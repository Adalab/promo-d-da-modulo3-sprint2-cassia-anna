# %%
import pandas as pd

# %%
df_densidad = pd.read_csv('datos/2021_densitat.csv', index_col=0)
df_densidad.head()
# Out:
#       Codi_Districte Nom_Districte  Codi_Barri  \
# Any
# 2021               1  Ciutat Vella           1
# 2021               1  Ciutat Vella           2
# 2021               1  Ciutat Vella           3
# 2021               1  Ciutat Vella           4
# 2021               2      Eixample           5
#
#                                   Nom_Barri  Població  Superfície (ha)  \
# Any
# 2021                               el Raval     47228            110.0
# 2021                         el Barri Gòtic     21827             81.6
# 2021                         la Barceloneta     14643            117.9
# 2021  Sant Pere, Santa Caterina i la Ribera     22131            111.0
# 2021                          el Fort Pienc     31262             92.9
#
#       Superfície Residencial (ha)  Densitat (hab/ha)  Densitat neta (hab/ha)
# Any
# 2021                         49.6                429                     952
# 2021                         34.1                268                     639
# ...

# %%
df_densidad.reset_index(inplace=True)

# %%
df_densidad['Any'].unique()
# Out:
# array([2021])

# %%
df_income = pd.read_csv('datos/2020_atles_renda_bruta_llar.csv', index_col=0)
df_income.head()
# Out:
#       Codi_Districte Nom_Districte  Codi_Barri Nom_Barri  Seccio_Censal  \
# Any
# 2020               1  Ciutat Vella           1  el Raval              1
# 2020               1  Ciutat Vella           1  el Raval              2
# 2020               1  Ciutat Vella           1  el Raval              3
# 2020               1  Ciutat Vella           1  el Raval              4
# 2020               1  Ciutat Vella           1  el Raval              5
#
#       Import_Renda_Bruta_€
# Any
# 2020                 32909
# 2020                 25493
# 2020                 28198
# 2020                 32716
# 2020                 26850

# %%
df_domicilios = pd.read_csv('datos/2022_domicilis_edat_mitjana_nacionalitat.csv', index_col=0)
df_domicilios.head()
# Out:
#       Codi_Districte Nom_Districte  Codi_Barri  \
# Any
# 2022               1  Ciutat Vella           1
# 2022               1  Ciutat Vella           2
# 2022               1  Ciutat Vella           3
# 2022               1  Ciutat Vella           4
# 2022               2      Eixample           5
#
#                                   Nom_Barri    Nacionalitat  Edat_mitjana
# Any
# 2022                               el Raval  Tots espanyols          50.7
# 2022                         el Barri Gòtic  Tots espanyols          51.3
# 2022                         la Barceloneta  Tots espanyols          51.4
# 2022  Sant Pere, Santa Caterina i la Ribera  Tots espanyols          50.2
# 2022                          el Fort Pienc  Tots espanyols          50.0

# %%
df_domicilios['Nacionalitat'].unique()
# Out:
# array(['Tots espanyols', 'Tots estrangers', 'Domicilis mixtos'],
#       dtype=object)

# %%
df_domicilios2 = pd.read_csv('datos/2022_domicilis_nacionalitat_espanyola_estrangera.csv', index_col=0)
df_domicilios2.head()
# Out:
#       Codi_Districte Nom_Districte  Codi_Barri  \
# Any
# 2022               1  Ciutat Vella           1
# 2022               1  Ciutat Vella           2
# 2022               1  Ciutat Vella           3
# 2022               1  Ciutat Vella           4
# 2022               2      Eixample           5
#
#                                   Nom_Barri Nacionalitat  Nombre
# Any
# 2022                               el Raval   1 espanyol    6001
# 2022                         el Barri Gòtic   1 espanyol    2306
# 2022                         la Barceloneta   1 espanyol    2442
# 2022  Sant Pere, Santa Caterina i la Ribera   1 espanyol    3673
# 2022                          el Fort Pienc   1 espanyol    4274

# %%
df_domicilios2['Nacionalitat'].unique()
# Out:
# array(['1 espanyol', '2 espanyols', '3 espanyols', '4 espanyols o més',
#        '1 estranger', '2 estrangers', '3 estrangers',
#        '4 estrangers o més'], dtype=object)

# %%
df_paro = pd.read_csv('datos/2022_pes_del_atur_registrat_sobre_poblacio_16_64_anys.csv', index_col=0)
df_paro.head()
# Out:
#       Mes  Codi_Districte Nom_Districte  Codi_Barri  \
# Any
# 2022    1               1  Ciutat Vella           1
# 2022    1               1  Ciutat Vella           2
# 2022    1               1  Ciutat Vella           3
# 2022    1               1  Ciutat Vella           4
# 2022    1               2      Eixample           5
#
#                                   Nom_Barri  Poblacio_16_64_anys  Pes_atur
# Any
# 2022                               el Raval                34952       8.7
# 2022                         el Barri Gòtic                18929       4.4
# 2022                         la Barceloneta                10821       7.9
# 2022  Sant Pere, Santa Caterina i la Ribera                17298       6.8
# 2022                          el Fort Pienc                22678       4.7

# %%
df_paro.reset_index(inplace=True)

# %%
df_paro.columns
# Out:
# Index(['Any', 'Mes', 'Codi_Districte', 'Nom_Districte', 'Codi_Barri',
#        'Nom_Barri', 'Poblacio_16_64_anys', 'Pes_atur'],
#       dtype='object')

# %%
df_paro_group = df_paro.groupby('Nom_Barri')['Pes_atur'].mean()

# %%
df_paro_group
# Out:
# Nom_Barri
# Baró de Viver                     6.041667
# Can Baró                          5.208333
# Can Peguera                       7.108333
# Canyelles                         9.850000
# Ciutat Meridiana                 11.825000
#                                    ...
# la Vila Olímpica del Poblenou     5.258333
# la Vila de Gràcia                 4.808333
# les Corts                         5.300000
# les Roquetes                      7.866667
# les Tres Torres                   3.341667
# Name: Pes_atur, Length: 73, dtype: float64

# %%
df_final = df_densidad.merge(df_paro, on=['Codi_Barri'], how='left')

# %%
df_final.head()
# Out:
#     Any  Codi_Districte_x Nom_Districte_x  Codi_Barri Nom_Barri_x  Població  \
# 0  2021                 1    Ciutat Vella           1    el Raval     47228
# 1  2021                 1    Ciutat Vella           1    el Raval     47228
# 2  2021                 1    Ciutat Vella           1    el Raval     47228
# 3  2021                 1    Ciutat Vella           1    el Raval     47228
# 4  2021                 1    Ciutat Vella           1    el Raval     47228
#
#    Superfície (ha)  Superfície Residencial (ha)  Densitat (hab/ha)  \
# 0            110.0                         49.6                429
# 1            110.0                         49.6                429
# 2            110.0                         49.6                429
# 3            110.0                         49.6                429
# 4            110.0                         49.6                429
#
#    Densitat neta (hab/ha)  Mes  Codi_Districte_y Nom_Districte_y Nom_Barri_y  \
# ...
